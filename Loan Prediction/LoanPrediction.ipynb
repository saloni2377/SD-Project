# %%
#Importing the datasets
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Train.csv',delimiter=',')
test_df=pd.read_csv('Test.csv',delimiter=',')

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df.head(5)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002    Yes       0         No      Graduate          Male
# 1  LP001003    Yes       0         No      Graduate          Male
# 2  LP001005    Yes       0         No      Graduate          Male
# 3  LP001006    Yes       0         No  Not Graduate          Male
# 4  LP001008    Yes       0         No      Graduate          Male
#
#    ApplicantIncome  CoapplicantIncome LoanAmount Loan_Amount_Term  \
# 0             5849                0.0       Male              360
# 1             4583             1508.0        128              360
# 2             3000                0.0         66              360
# 3             2583             2358.0        120              360
# 4             6000                0.0        141              360
#
#   Credit_History Property_Area Loan_Status
# 0              1         Urban           Y
# 1              1         Rural           N
# 2              1         Urban           Y
# 3              1         Urban           Y
# 4              1         Urban           Y

# %%
test_df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       367.000000         367.000000  362.000000        361.000000
# mean       4805.599455        1569.577657  136.132597        342.537396
# std        4910.685399        2334.232099   61.366652         65.156643
# min           0.000000           0.000000   28.000000          6.000000
# 25%        2864.000000           0.000000  100.250000        360.000000
# 50%        3786.000000        1025.000000  125.000000        360.000000
# 75%        5060.000000        2430.500000  158.000000        360.000000
# max       72529.000000       24000.000000  550.000000        480.000000
#
#        Credit_History
# count      338.000000
# mean         0.825444
# std          0.380150
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
test_df.apply(lambda x: sum(x.isnull()), axis= 0)
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# dtype: int64

# %%
#Check for missing values in the dataset
df.apply(lambda x: sum(x.isnull()), axis= 0)
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df['LoanAmount'].fillna(value=146.0, inplace= True)
df['Loan_Amount_Term'].fillna(342.0,inplace= True)
df['Married'].fillna('Yes',inplace= True)
df['Credit_History'].fillna(1.0,inplace= True)
df['Self_Employed'].fillna('No',inplace= True)
#df['Gender'].fillna('Male',inplace= True)
df['Dependents'].fillna('0',inplace= True)

# %%
df.apply(lambda x: sum(x.isnull()), axis= 0)
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
test_df['LoanAmount'].fillna(136, inplace= True)
test_df['Loan_Amount_Term'].fillna(342,inplace= True)
test_df['Credit_History'].fillna(1.0,inplace= True)
test_df['Self_Employed'].fillna('No',inplace= True)
test_df['Gender'].fillna('Male',inplace= True)
test_df['Dependents'].fillna('0',inplace= True)

# %%
test_df.apply(lambda x: sum(x.isnull()), axis= 0)
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# dtype: int64

# %%
df
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Yes       0         No      Graduate          Male
# 1    LP001003    Yes       0         No      Graduate          Male
# 2    LP001005    Yes       0         No      Graduate          Male
# 3    LP001006    Yes       0         No  Not Graduate          Male
# 4    LP001008    Yes       0         No      Graduate          Male
# 5    LP001011    Yes       0         No      Graduate          Male
# 6    LP001013    Yes       0         No  Not Graduate          Male
# 7    LP001014    Yes       0         No      Graduate          Male
# 8    LP001018    Yes       0         No      Graduate          Male
# 9    LP001020    Yes       0         No      Graduate          Male
# 10   LP001024    Yes       0         No      Graduate          Male
# 11   LP001027    Yes       0         No      Graduate          Male
# 12   LP001028    Yes       0         No      Graduate          Male
# 13   LP001029    Yes       0         No      Graduate          Male
# 14   LP001030    Yes       0         No      Graduate          Male
# 15   LP001032    Yes       0         No      Graduate          Male
# 19              2600             3500.0        115             Male
# 20              7660                0.0        104              360
# 21              5955             5625.0        315              360
# 22              2600             1911.0        116              360
# 23              3365             1917.0        112              360
# 24              3717             2925.0        151              360
# 25              9560                0.0        191              360
# 26              2799             2253.0        122              360
# 27              4226             1040.0        110              360
# 28              1442                0.0         35              360
# 29              3750             2083.0        120              360
# ..               ...                ...        ...              ...
# 584             2787             1917.0        146              360
# 585             4283             3000.0        172               84
# 586             2297             1522.0        104              360
# 587             2165                0.0         70              360
# 588             4750                0.0         94              360
# 589             2726                0.0        106              360
# 590             3000             3416.0         56              180
# 591             6000                0.0        205              240
# 592             9357                0.0        292              360
# 593             3859             3300.0        142              180
# 594            16120                0.0        260              360
# 595             3833                0.0        110              360
# 596             6383             1000.0        187              360
# 597             2987                0.0         88              360
# 598             9963                0.0        180              360
# 599             5780                0.0        192              360
# 600              416            41667.0        350              180
# 601             2894             2792.0        155              360
# 602             5703                0.0        128              360
# 603             3676             4301.0        172              360
# 604            12000                0.0        496              360
# 605             2400             3800.0       Male              180
# 606             3400             2500.0        173              360
# 607             3987             1411.0        157              360
# 608             3232             1950.0        108              360
# 609             2900                0.0         71              360
# 610             4106                0.0         40              180
# 611             8072              240.0        253              360
# 612             7583                0.0        187              360
# 613             4583                0.0        133              360
#
#     Credit_History Property_Area Loan_Status
# 0                1         Urban           Y
# 1                1         Rural           N
# 2                1         Urban           Y
# 3                1         Urban           Y
# 4                1         Urban           Y
# 5                1         Urban           Y
# 6                1         Urban           Y
# 7                0     Semiurban           N
# 8                1         Urban           Y
# 9                1     Semiurban           N
# 10               1         Urban           Y
# 11               1         Urban           Y
# 12               1         Urban           Y
# 13               1         Rural           N
# 14               1         Urban           Y
# 15               1         Urban           Y
# 16            Male         Urban           Y
# 17               0         Urban           N
# 18               1         Rural           N
# 19               1         Urban           Y
# 20               0         Urban           N
# 21               1         Urban           Y
# 22               0     Semiurban           N
# 23               0         Rural           N
# 24            Male     Semiurban           N
# 25               1     Semiurban           Y
# 26               1     Semiurban           Y
# 27               1         Urban           Y
# 28               1         Urban           N
# 29               1     Semiurban           Y
# ..             ...           ...         ...
# 584              0         Rural           N
# 585              1         Rural           N
# 586              1         Urban           Y
# 587              1     Semiurban           Y
# 588              1     Semiurban           Y
# 589              0     Semiurban           N
# 590              1     Semiurban           Y
# 591              1     Semiurban           N
# 592              1     Semiurban           Y
# 593              1         Rural           Y
# 594              1         Urban           Y
# 595              1         Rural           Y
# 596              1         Rural           N
# 597              0     Semiurban           N
# 598              1         Rural           Y
# 599              1         Urban           Y
# 600           Male         Urban           N
# 601              1         Rural           Y
# 602              1         Urban           Y
# 603              1         Rural           Y
# 604              1     Semiurban           Y
# 605              1         Urban           N
# 606              1     Semiurban           Y
# 607              1         Rural           Y
# 608              1         Rural           Y
# 609              1         Rural           Y
# 610              1         Rural           Y
# 611              1         Urban           Y
# 612              1         Urban           Y
# 613              0     Semiurban           N
#
# [614 rows x 13 columns]
